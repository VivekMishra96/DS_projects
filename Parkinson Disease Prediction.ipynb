# %%
import pandas as pd 
import numpy as np

# %%
# Loading the data
data= pd.read_csv("parkinsons.data")
data
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
# Findian null values
data.isna().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# Data Statistics
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df =data.drop('name', axis = 'columns')
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
# Removing Outliers

columns = list(df)
for i in df:
        value = df[i]
        max_threshold = value.quantile(0.99)
        min_threshold = value.quantile(0.01)
        df2= df[(value>min_threshold) & (value<max_threshold)]
df2
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df2.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   191.000000    191.000000    191.000000      191.000000
# mean    153.437398    196.838435    115.025236        0.006087
# std      41.409005     92.415239     42.935310        0.004478
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.250000    134.443500     84.016500        0.003475
# 50%     148.272000    172.860000    103.370000        0.004940
# 75%     180.588000    224.956000    133.679500        0.007300
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        191.000000  191.000000  191.000000  191.000000    191.000000
# mean           0.000043    0.003226    0.003355    0.009680      0.029181
# std            0.000034    0.002764    0.002479    0.008293      0.017390
# min            0.000007    0.000680    0.000920    0.002040      0.010150
# ...

# %%
# Dimensionality Reduction

total_variation_in_frequencies = df2['MDVP:Jitter(%)']+df2['MDVP:Jitter(Abs)']+df2['MDVP:RAP']+ df2['MDVP:PPQ']+ df2['Jitter:DDP']
round_off_frequencies = np.round(total_variation_in_frequencies, decimals = 3)
mean_of_frequencies = (round_off_frequencies)/5
mean_of_frequencies
# Out:
# 0      0.0056
# 1      0.0070
# 2      0.0080
# 3      0.0074
# 4      0.0096
#         ...
# 190    0.0036
# 191    0.0044
# 192    0.0088
# 193    0.0052
# 194    0.0042
# Length: 191, dtype: float64

# %%
# Dimensionality Reduction

variation_in_amplitude = df2['MDVP:Shimmer']+df2['MDVP:Shimmer(dB)']+df2['Shimmer:APQ3']+ df2['Shimmer:APQ5']+ df2['MDVP:APQ']+df['Shimmer:DDA']
round_off_amplitude = np.round(variation_in_amplitude, decimals = 3)
mean_of_amplitude = (round_off_frequencies)/6
mean_of_amplitude
# Out:
# 0      0.004667
# 1      0.005833
# 2      0.006667
# 3      0.006167
# 4      0.008000
#          ...
# 190    0.003000
# 191    0.003667
# 192    0.007333
# 193    0.004333
# 194    0.003500
# Length: 191, dtype: float64

# %%
# Dimensionality Reduction

sum_of_two_nonlinear_dynamical_complexity_measures = df2['RPDE']+df2['D2'] 
round_off_complexity_measures = np.round(sum_of_two_nonlinear_dynamical_complexity_measures, decimals = 3)
mean_of_complexity_measures = (round_off_frequencies)/2
mean_of_complexity_measures
# Out:
# 0      0.0140
# 1      0.0175
# 2      0.0200
# 3      0.0185
# 4      0.0240
#         ...
# 190    0.0090
# 191    0.0110
# 192    0.0220
# 193    0.0130
# 194    0.0105
# Length: 191, dtype: float64

# %%
# Dimensionality Reduction

sum_of_three_nonlinear_measures_of_fundamental_frequency_variation= df2['spread1']+ df2['spread2']+ df2['PPE']
round_off_three_nonlinear_measures_of_fundamental_frequency_variation = np.round(sum_of_three_nonlinear_measures_of_fundamental_frequency_variation, decimals = 3)
mean_of_three_nonlinear_measures_of_fundamental_frequency_variation= (round_off_frequencies)/3
mean_of_three_nonlinear_measures_of_fundamental_frequency_variation
# Out:
# 0      0.009333
# 1      0.011667
# 2      0.013333
# 3      0.012333
# 4      0.016000
#          ...
# 190    0.006000
# 191    0.007333
# 192    0.014667
# 193    0.008667
# 194    0.007000
# Length: 191, dtype: float64

# %%
# Dimensionality Reduction

sum_of_ratio_of_noise_to_tonal_components = df2['NHR']+df2['HNR'] 
round_off_ratio_of_noise_to_tonal_components = np.round(sum_of_ratio_of_noise_to_tonal_components, decimals = 3)
mean_of_ratio_of_noise_to_tonal_components = (round_off_frequencies)/2
mean_of_ratio_of_noise_to_tonal_components
# Out:
# 0      0.0140
# 1      0.0175
# 2      0.0200
# 3      0.0185
# 4      0.0240
#         ...
# 190    0.0090
# 191    0.0110
# 192    0.0220
# 193    0.0130
# 194    0.0105
# Length: 191, dtype: float64

# %%
df3= df2.drop(['MDVP:Jitter(%)','MDVP:Jitter(Abs)','MDVP:RAP', 'MDVP:PPQ','Jitter:DDP','MDVP:Shimmer','MDVP:Shimmer(dB)', 'Shimmer:APQ3','Shimmer:APQ5','MDVP:APQ','Shimmer:DDA','NHR', 'HNR','RPDE','D2','spread1','spread2','PPE'], axis = 'columns')
df3['Variation in fundamental frequencies']= mean_of_frequencies
df3['measures of variation in amplitude'] = mean_of_amplitude
df3['Two nonlinear dynamical complexity measures'] = mean_of_complexity_measures
df3['Three nonlinear measures of fundamental frequency variation'] = mean_of_three_nonlinear_measures_of_fundamental_frequency_variation
df3
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  status       DFA  \
# 0        119.992       157.302        74.997       1  0.815285
# 1        122.400       148.650       113.819       1  0.819521
# 2        116.682       131.111       111.555       1  0.825288
# 3        116.676       137.871       111.366       1  0.819235
# 4        116.014       141.781       110.655       1  0.823484
# ..           ...           ...           ...     ...       ...
# 190      174.188       230.978        94.261       0  0.657899
# 191      209.516       253.017        89.488       0  0.683244
# 192      174.688       240.005        74.287       0  0.655683
# 193      198.764       396.961        74.904       0  0.643956
# 194      214.289       260.277        77.973       0  0.664357
#
#      Variation in fundamental frequencies  measures of variation in amplitude  \
# 0                                  0.0056                            0.004667
# ...

# %%
df3.rename(columns = {'MDVP:Fo(Hz)':'Average vocal fundamental frequency', 'MDVP:Fhi(Hz)':'Maximum vocal fundamental frequency', 'MDVP:Flo(Hz)': 'Minimum vocal fundamental frequency', 'DFA':'Signal fractal scaling exponent'}, inplace = True)
df3
df4=df3.copy()
df4
# Out:
#      Average vocal fundamental frequency  Maximum vocal fundamental frequency  \
# 0                                119.992                              157.302
# 1                                122.400                              148.650
# 2                                116.682                              131.111
# 3                                116.676                              137.871
# 4                                116.014                              141.781
# ..                                   ...                                  ...
# 190                              174.188                              230.978
# 191                              209.516                              253.017
# 192                              174.688                              240.005
# 193                              198.764                              396.961
# 194                              214.289                              260.277
#
# ...

# %%
x= df4.drop('status', axis = 'columns')
x.shape
# Out:
# (191, 8)

# %%
df3['status'] = df4['status'].apply(lambda x : 'Parkinson Disease' if x ==1 in df3.status else 'Not Parkinson Disease')
y = df3['status']
y
# Out:
# 0      Not Parkinson Disease
# 1      Not Parkinson Disease
# 2      Not Parkinson Disease
# 3      Not Parkinson Disease
# 4      Not Parkinson Disease
#                ...
# 190        Parkinson Disease
# 191        Parkinson Disease
# 192        Parkinson Disease
# 193        Parkinson Disease
# 194        Parkinson Disease
# Name: status, Length: 191, dtype: object

# %%
# Scaling the data

from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_scaled = scaler.fit_transform(x)
df5 =pd.DataFrame(x_scaled)
df5
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.809807 -0.428937 -0.934742  1.773197  0.315226  0.315226  0.315226
# 1   -0.751502 -0.522804 -0.028168  1.849769  0.706915  0.706915  0.706915
# 2   -0.889951 -0.713088 -0.081037  1.954016  0.986693  0.986693  0.986693
# 3   -0.890097 -0.639747 -0.085451  1.844600  0.818826  0.818826  0.818826
# 4   -0.906125 -0.597327 -0.102054  1.921407  1.434338  1.434338  1.434338
# ..        ...       ...       ...       ...       ...       ...       ...
# 186  0.502430  0.370386 -0.484888 -1.071788 -0.244330 -0.244330 -0.244330
# 187  1.357820  0.609490 -0.596347 -0.613640 -0.020507 -0.020507 -0.020507
# 188  0.514537  0.468321 -0.951322 -1.111846  1.210516  1.210516  1.210516
# 189  1.097484  2.171163 -0.936914 -1.323829  0.203315  0.203315  0.203315
# 190  1.473388  0.688255 -0.865246 -0.955050 -0.076463 -0.076463 -0.076463
#
#             7
# 0    0.315226
# 1    0.706915
# 2    0.986693
# 3    0.818826
# ...

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans

# %%
model_params = {
    
    'Random_Forest_Classifier' : {
        'model': RandomForestClassifier(),
        'params': {
            'criterion': ['gini', 'entropy']
        }
    },
    'SVC': {
        'model': SVC(),
        'params': {
            'kernel':['linear', 'poly', 'rbf'],
            'gamma':['scale', 'auto']
        }
    },
    'Decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini', 'entropy'],
            'splitter': ['best', 'random']
            
        }
    },
    'K_Neighbour_classifier':{
        'model': KNeighborsClassifier(),
        'params':{
            'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
        }
    }
        
    
    
}

# %%
#Selection of Best Models

from sklearn.model_selection import GridSearchCV

scores = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(x_scaled, y)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df6 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df6
# Out:
#                       model  best_score  \
# 0  Random_Forest_Classifier    0.806073
# 1                       SVC    0.795277
# 2             Decision_tree    0.785155
# 3    K_Neighbour_classifier    0.732524
#
#                                    best_params
# 0                        {'criterion': 'gini'}
# 1         {'gamma': 'scale', 'kernel': 'poly'}
# 2  {'criterion': 'gini', 'splitter': 'random'}
# 3                        {'algorithm': 'auto'}

# %%
clf = RandomForestClassifier()
result = clf.fit(x_scaled,y)

# %%
def prediction(Average_vocal_fundamental_frequency, Maximum_vocal_fundamental_frequency, Minimum_vocal_fundamental_frequency, Signal_fractal_scaling_exponent, Variation_in_fundamental_frequencies, measures_of_variation_in_amplitude, Two_nonlinear_dynamical_complexity_measures, Three_nonlinear_measures_of_fundamental_frequency_variation):    

    X = np.zeros(len(x.columns))
    X[0] = Average_vocal_fundamental_frequency
    X[1] = Maximum_vocal_fundamental_frequency
    X[2] = Minimum_vocal_fundamental_frequency
    X[3] = Signal_fractal_scaling_exponent
    X[4] = Variation_in_fundamental_frequencies
    X[5] = measures_of_variation_in_amplitude
    X[6] = Two_nonlinear_dynamical_complexity_measures
    X[7] = Three_nonlinear_measures_of_fundamental_frequency_variation
    
    return result.predict([X])[0]
        
Average_vocal_fundamental_frequency = float(input("Enter the Average_vocal_fundamental_frequency: "))
Maximum_vocal_fundamental_frequency = float(input("Enter the Maximum_vocal_fundamental_frequency: "))
Minimum_vocal_fundamental_frequency = float(input("Enter the Minimum_vocal_fundamental_frequency: "))
Signal_fractal_scaling_exponent= float(input("Enter the Signal_fractal_scaling_exponent: "))
Variation_in_fundamental_frequencies = float(input("Enter the Variation_in_fundamental_frequencies: "))
measures_of_variation_in_amplitude= float(input("Enter the measures_of_variation_in_amplitude: "))
Two_nonlinear_dynamical_complexity_measures = float(input("Enter the Two_nonlinear_dynamical_complexity_measures: "))
Three_nonlinear_measures_of_fundamental_frequency_variation = float(input("Enter the Three_nonlinear_measures_of_fundamental_frequency_variation: "))
# Out:
# Enter the Average_vocal_fundamental_frequency: 198
# Enter the Maximum_vocal_fundamental_frequency: 375
# Enter the Minimum_vocal_fundamental_frequency: 45
# Enter the Signal_fractal_scaling_exponent: 0.006
# Enter the Variation_in_fundamental_frequencies: 0.008
# Enter the measures_of_variation_in_amplitude: 0.5
# Enter the Two_nonlinear_dynamical_complexity_measures: 0.0049
# Enter the Three_nonlinear_measures_of_fundamental_frequency_variation: 0.008

# %%
#Predicting 
prediction(Average_vocal_fundamental_frequency, Maximum_vocal_fundamental_frequency, Minimum_vocal_fundamental_frequency, Signal_fractal_scaling_exponent, Variation_in_fundamental_frequencies, measures_of_variation_in_amplitude, Two_nonlinear_dynamical_complexity_measures, Three_nonlinear_measures_of_fundamental_frequency_variation)
# Out:
# 'Parkinson Disease'
